# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime 
from datetime import date 
import pprint as pp
# Import API key
from config import api_key
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
query_url = f"{url}appid={api_key}&units={units}&q="
#print(query_url)
# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities=[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
       
    
#Print the city count to confirm sufficient count
len(cities)
#print(cities)
cities_df=pd.DataFrame(cities)
cities_df.to_csv(output_data_file)
cities_df=cities_df.rename(columns={0:"City"})
cities_df["Cloudiness"]=""
cities_df["Country"]=""
cities_df["Date"]=""
cities_df["Humidity"]=""
cities_df["Lat"]=""
cities_df["Long"]=""
cities_df["Max Temp"]=""
cities_df["Wind Speed"]=""





#del cities_df[0]

#cities_df["cities"][0]

# %%
cities_df.head()
# Out:
#         City Cloudiness Country Date Humidity Lat Long Max Temp Wind Speed
# 0   vanavara
# 1  carnarvon
# 2      kapaa
# 3      nalut
# 4  upernavik

# %%
temp = []
#str=query_url + cities_df["City"][0]
#city1="vaitupu"
#print(str)
#response = requests.get(query_url + city1).json()
#print(response)
#pp.pprint(response)

#print(response["name"])
#print(response["clouds"]["all"])
#print(response["sys"]["country"])
#print(response["dt"])
#print(response["main"]["humidity"])
#print(response["coord"]["lat"])
#print(response["coord"]["lon"])
#print(response["main"]["temp_max"])
#print(response["wind"]["speed"])
#print(response["main"]["pressure"])
ctycntr=1
setcnt =1
#print(response[""])
for index, row in cities_df.iterrows():
    city = row['City']
    
    if (ctycntr%50)==0:
        #print(ctycntr%50)
        ctycntr=1
        setcnt +=1
    else:
        ctycntr+=1 
    response = requests.get(query_url + city).json()
    print(f"Processing Record {ctycntr-1} of Set {setcnt} | {city} ")
    #print(query_url + city)
    if response["cod"]!="404" and response["cod"]!="500" :
        cities_df.loc[index, "Cloudiness"]=response["clouds"]["all"]
        #cities_df["Cloudiness"]=response["clouds"]["all"]
        cities_df.loc[index, "Country"]=response["sys"]["country"]
        #cities_df["Country"]=response["sys"]["country"]
        current_date=datetime.datetime.fromtimestamp(response["dt"]).strftime("%x")
        cities_df.loc[index, "Date"]=response["dt"]
        #cities_df["Date"]=response["dt"]
        cities_df.loc[index, "Humidity"]=response["main"]["humidity"]
        #cities_df["Humidity"]=response["main"]["humidity"]
        cities_df.loc[index, "Lat"]=float(response["coord"]["lat"])
        #cities_df["Lat"]=response["coord"]["lat"]
        cities_df.loc[index, "Long"]=response["coord"]["lon"]
        #cities_df["Long"]=response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"]=float(response["main"]["temp_max"])
        #cities_df["Max Temp"]=response["main"]["temp_max"]
        cities_df.loc[index, "Wind Speed"]=response["wind"]["speed"]
        #cities_df["Wind Speed"]=response["wind"]["speed"]
    else:
        print("City Not Found")
        
#Processing Record 1 of Set 1 | lompoc

 #   lat.append(response['coord']['lat'])
 #   temp.append(response['main']['temp'])

#print(f"The latitude information received is: {lat}")
#print(f"The temperature information received is: {temp}")
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=1d705ab9643efe2d53759ca1bb717a6f&units=imperial&q=vanavara
# {'cod': '404', 'message': 'city not found'}
# Processing Record 1 of Set 1 | vanavara
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | nalut
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | marshfield
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | hay river
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | sentyabrskiy
# City Not Found
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | san cristobal
# Processing Record 18 of Set 1 | saint-francois
# Processing Record 19 of Set 1 | illoqqortoormiut
# City Not Found
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | ust-maya
# Processing Record 22 of Set 1 | hamilton
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | gat
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | adrar
# Processing Record 27 of Set 1 | champerico
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | shimoda
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | mollendo
# Processing Record 34 of Set 1 | ahipara
# Processing Record 35 of Set 1 | prince rupert
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | broome
# Processing Record 38 of Set 1 | nouadhibou
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | khonuu
# City Not Found
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | namibe
# Processing Record 43 of Set 1 | brokopondo
# Processing Record 44 of Set 1 | ukiah
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | deputatskiy
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | hilo
# Processing Record 0 of Set 2 | ancud
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | santa fe
# Processing Record 3 of Set 2 | qurbus
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | stephenville
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | beliator
# Processing Record 9 of Set 2 | verkhnevilyuysk
# Processing Record 10 of Set 2 | taybad
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | geraldton
# Processing Record 14 of Set 2 | marv dasht
# City Not Found
# Processing Record 15 of Set 2 | sitka
# Processing Record 16 of Set 2 | kaitangata
# Processing Record 17 of Set 2 | codrington
# Processing Record 18 of Set 2 | eirunepe
# Processing Record 19 of Set 2 | calabozo
# Processing Record 20 of Set 2 | oranjestad
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | san juan
# Processing Record 23 of Set 2 | villa maria
# Processing Record 24 of Set 2 | sanary-sur-mer
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | hami
# Processing Record 27 of Set 2 | klimovo
# Processing Record 28 of Set 2 | oksovskiy
# Processing Record 29 of Set 2 | stuttgart
# Processing Record 30 of Set 2 | barentsburg
# City Not Found
# Processing Record 31 of Set 2 | paraiso
# Processing Record 32 of Set 2 | ulladulla
# Processing Record 33 of Set 2 | matveyevka
# Processing Record 34 of Set 2 | tabukiniberu
# City Not Found
# Processing Record 35 of Set 2 | kavaratti
# Processing Record 36 of Set 2 | souillac
# Processing Record 37 of Set 2 | kanturk
# Processing Record 38 of Set 2 | baran
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | port hawkesbury
# Processing Record 41 of Set 2 | nizhneyansk
# City Not Found
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | vila velha
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | chingirlau
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | caxambu
# Processing Record 48 of Set 2 | darnah
# Processing Record 49 of Set 2 | vaitupu
# City Not Found
# Processing Record 0 of Set 3 | gizo
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | dwarka
# Processing Record 3 of Set 3 | belushya guba
# City Not Found
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | busayra
# Processing Record 6 of Set 3 | kuloy
# Processing Record 7 of Set 3 | bo phloi
# Processing Record 8 of Set 3 | minudasht
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | samusu
# City Not Found
# Processing Record 12 of Set 3 | benxi
# Processing Record 13 of Set 3 | basco
# Processing Record 14 of Set 3 | mecca
# Processing Record 15 of Set 3 | navalmoral de la mata
# Processing Record 16 of Set 3 | port hedland
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | mandali
# Processing Record 19 of Set 3 | attawapiskat
# City Not Found
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | sulphur springs
# Processing Record 24 of Set 3 | marquette
# Processing Record 25 of Set 3 | mount gambier
# Processing Record 26 of Set 3 | samarai
# Processing Record 27 of Set 3 | norman wells
# Processing Record 28 of Set 3 | mopti
# Processing Record 29 of Set 3 | saint-philippe
# Processing Record 30 of Set 3 | eureka
# Processing Record 31 of Set 3 | caravelas
# Processing Record 32 of Set 3 | olafsvik
# City Not Found
# Processing Record 33 of Set 3 | kuche
# City Not Found
# Processing Record 34 of Set 3 | thunder bay
# Processing Record 35 of Set 3 | yomou
# Processing Record 36 of Set 3 | sioux lookout
# Processing Record 37 of Set 3 | faranah
# Processing Record 38 of Set 3 | tsihombe
# City Not Found
# Processing Record 39 of Set 3 | alice springs
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | lorengau
# Processing Record 42 of Set 3 | nanortalik
# Processing Record 43 of Set 3 | ust-kuyga
# Processing Record 44 of Set 3 | vardo
# Processing Record 45 of Set 3 | viligili
# City Not Found
# Processing Record 46 of Set 3 | bandar-e torkaman
# City Not Found
# Processing Record 47 of Set 3 | palabuhanratu
# City Not Found
# Processing Record 48 of Set 3 | mgachi
# Processing Record 49 of Set 3 | sao paulo de olivenca
# Processing Record 0 of Set 4 | ilulissat
# Processing Record 1 of Set 4 | linxia
# Processing Record 2 of Set 4 | pascagoula
# Processing Record 3 of Set 4 | chuy
# Processing Record 4 of Set 4 | karratha
# Processing Record 5 of Set 4 | pangnirtung
# Processing Record 6 of Set 4 | dongsheng
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | griffith
# Processing Record 9 of Set 4 | mogadishu
# Processing Record 10 of Set 4 | butaritari
# Processing Record 11 of Set 4 | clermont
# Processing Record 12 of Set 4 | victoria
# Processing Record 13 of Set 4 | portoferraio
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | zhuanghe
# Processing Record 16 of Set 4 | filadelfia
# Processing Record 17 of Set 4 | tynset
# Processing Record 18 of Set 4 | sisimiut
# Processing Record 19 of Set 4 | saint anthony
# Processing Record 20 of Set 4 | narsaq
# Processing Record 21 of Set 4 | padang
# Processing Record 22 of Set 4 | netrakona
# Processing Record 23 of Set 4 | homer
# Processing Record 24 of Set 4 | sobolevo
# Processing Record 25 of Set 4 | necochea
# Processing Record 26 of Set 4 | kidal
# Processing Record 27 of Set 4 | alofi
# Processing Record 28 of Set 4 | srednekolymsk
# Processing Record 29 of Set 4 | tual
# Processing Record 30 of Set 4 | grand river south east
# City Not Found
# Processing Record 31 of Set 4 | tautira
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | mandera
# Processing Record 35 of Set 4 | husavik
# Processing Record 36 of Set 4 | marsa matruh
# Processing Record 37 of Set 4 | pacific grove
# Processing Record 38 of Set 4 | avarua
# Processing Record 39 of Set 4 | goba
# Processing Record 40 of Set 4 | burica
# City Not Found
# Processing Record 41 of Set 4 | kazalinsk
# City Not Found
# Processing Record 42 of Set 4 | sorong
# Processing Record 43 of Set 4 | mokhsogollokh
# Processing Record 44 of Set 4 | vostok
# Processing Record 45 of Set 4 | lodja
# Processing Record 46 of Set 4 | taolanaro
# City Not Found
# Processing Record 47 of Set 4 | villamontes
# Processing Record 48 of Set 4 | baruun-urt
# Processing Record 49 of Set 4 | mount isa
# Processing Record 0 of Set 5 | siniscola
# Processing Record 1 of Set 5 | cidreira
# Processing Record 2 of Set 5 | port moresby
# Processing Record 3 of Set 5 | faanui
# Processing Record 4 of Set 5 | cherskiy
# Processing Record 5 of Set 5 | yamethin
# Processing Record 6 of Set 5 | belturbet
# Processing Record 7 of Set 5 | dali
# Processing Record 8 of Set 5 | achacachi
# Processing Record 9 of Set 5 | ilhabela
# Processing Record 10 of Set 5 | sembe
# City Not Found
# Processing Record 11 of Set 5 | aklavik
# Processing Record 12 of Set 5 | ponnani
# Processing Record 13 of Set 5 | cartagena
# Processing Record 14 of Set 5 | tavda
# Processing Record 15 of Set 5 | otofuke
# Processing Record 16 of Set 5 | sola
# Processing Record 17 of Set 5 | khanpur
# Processing Record 18 of Set 5 | damietta
# Processing Record 19 of Set 5 | paamiut
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | west fargo
# Processing Record 22 of Set 5 | ipsos
# City Not Found
# Processing Record 23 of Set 5 | hambantota
# Processing Record 24 of Set 5 | ler
# Processing Record 25 of Set 5 | midland
# Processing Record 26 of Set 5 | la crosse
# Processing Record 27 of Set 5 | harbour breton
# Processing Record 28 of Set 5 | neenah
# Processing Record 29 of Set 5 | vao
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | vestmannaeyjar
# Processing Record 32 of Set 5 | vargashi
# Processing Record 33 of Set 5 | chokurdakh
# Processing Record 34 of Set 5 | kirakira
# Processing Record 35 of Set 5 | concepcion del uruguay
# Processing Record 36 of Set 5 | klaksvik
# Processing Record 37 of Set 5 | fairbanks
# Processing Record 38 of Set 5 | pedernales
# Processing Record 39 of Set 5 | baoro
# Processing Record 40 of Set 5 | zilupe
# Processing Record 41 of Set 5 | galich
# Processing Record 42 of Set 5 | urdzhar
# City Not Found
# Processing Record 43 of Set 5 | majene
# Processing Record 44 of Set 5 | byron bay
# Processing Record 45 of Set 5 | saryshagan
# City Not Found
# Processing Record 46 of Set 5 | sumenep
# Processing Record 47 of Set 5 | wa
# City Not Found
# Processing Record 48 of Set 5 | naftah
# City Not Found
# Processing Record 49 of Set 5 | port maria
# Processing Record 0 of Set 6 | garoua
# Processing Record 1 of Set 6 | akdepe
# Processing Record 2 of Set 6 | karaul
# City Not Found
# Processing Record 3 of Set 6 | beidao
# Processing Record 4 of Set 6 | bubaque
# Processing Record 5 of Set 6 | kangayam
# Processing Record 6 of Set 6 | college
# Processing Record 7 of Set 6 | comodoro rivadavia
# Processing Record 8 of Set 6 | qui nhon
# City Not Found
# Processing Record 9 of Set 6 | asayita
# City Not Found
# Processing Record 10 of Set 6 | prainha
# Processing Record 11 of Set 6 | port hardy
# Processing Record 12 of Set 6 | bacabal
# Processing Record 13 of Set 6 | bur gabo
# City Not Found
# Processing Record 14 of Set 6 | naze
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | faridpur
# Processing Record 17 of Set 6 | bone
# Processing Record 18 of Set 6 | port elizabeth
# Processing Record 19 of Set 6 | urucara
# Processing Record 20 of Set 6 | coquimbo
# Processing Record 21 of Set 6 | salalah
# Processing Record 22 of Set 6 | waipawa
# Processing Record 23 of Set 6 | igualada
# Processing Record 24 of Set 6 | severo-yeniseyskiy
# Processing Record 25 of Set 6 | barbar
# City Not Found
# Processing Record 26 of Set 6 | pisco
# Processing Record 27 of Set 6 | fort nelson
# Processing Record 28 of Set 6 | antofagasta
# Processing Record 29 of Set 6 | langxiang
# Processing Record 30 of Set 6 | khatanga
# Processing Record 31 of Set 6 | roebourne
# Processing Record 32 of Set 6 | izvoru barzii
# Processing Record 33 of Set 6 | ilo
# Processing Record 34 of Set 6 | ostrovnoy
# Processing Record 35 of Set 6 | imbituba
# Processing Record 36 of Set 6 | port blair
# Processing Record 37 of Set 6 | iqaluit
# Processing Record 38 of Set 6 | el tigre
# Processing Record 39 of Set 6 | bredasdorp
# Processing Record 40 of Set 6 | yulara
# Processing Record 41 of Set 6 | cuorgne
# Processing Record 42 of Set 6 | thinadhoo
# Processing Record 43 of Set 6 | berlevag
# Processing Record 44 of Set 6 | namatanai
# Processing Record 45 of Set 6 | camacha
# Processing Record 46 of Set 6 | qandala
# Processing Record 47 of Set 6 | dunedin
# Processing Record 48 of Set 6 | nizhnekamsk
# Processing Record 49 of Set 6 | moose factory
# Processing Record 0 of Set 7 | sakakah
# City Not Found
# Processing Record 1 of Set 7 | nam tha
# City Not Found
# Processing Record 2 of Set 7 | tanete
# Processing Record 3 of Set 7 | grindavik
# Processing Record 4 of Set 7 | sardarpur
# Processing Record 5 of Set 7 | zyryanovsk
# Processing Record 6 of Set 7 | atambua
# Processing Record 7 of Set 7 | ketchikan
# Processing Record 8 of Set 7 | sinjar
# Processing Record 9 of Set 7 | mago
# Processing Record 10 of Set 7 | binzhou
# Processing Record 11 of Set 7 | warqla
# City Not Found
# Processing Record 12 of Set 7 | beloha
# Processing Record 13 of Set 7 | kodiak
# Processing Record 14 of Set 7 | saleaula
# City Not Found
# Processing Record 15 of Set 7 | san vicente
# Processing Record 16 of Set 7 | puerto montt
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | yarqa
# Processing Record 19 of Set 7 | bontang
# Processing Record 20 of Set 7 | airai
# Processing Record 21 of Set 7 | san giljan
# Processing Record 22 of Set 7 | arman
# Processing Record 23 of Set 7 | porto velho
# Processing Record 24 of Set 7 | constitucion
# Processing Record 25 of Set 7 | turukhansk
# Processing Record 26 of Set 7 | saint-pierre
# Processing Record 27 of Set 7 | egvekinot
# Processing Record 28 of Set 7 | zilair
# Processing Record 29 of Set 7 | ayorou
# Processing Record 30 of Set 7 | dingle
# Processing Record 31 of Set 7 | dalbandin
# Processing Record 32 of Set 7 | urengoy
# Processing Record 33 of Set 7 | vallenar
# Processing Record 34 of Set 7 | tuatapere
# Processing Record 35 of Set 7 | kouroussa
# Processing Record 36 of Set 7 | borazjan
# Processing Record 37 of Set 7 | sale
# Processing Record 38 of Set 7 | pingliang
# Processing Record 39 of Set 7 | canton
# Processing Record 40 of Set 7 | haines junction
# Processing Record 41 of Set 7 | anadyr
# Processing Record 42 of Set 7 | isla mujeres
# Processing Record 43 of Set 7 | havre-saint-pierre
# Processing Record 44 of Set 7 | nipawin
# Processing Record 45 of Set 7 | jabiru
# City Not Found
# Processing Record 46 of Set 7 | lagoa
# Processing Record 47 of Set 7 | mehamn
# Processing Record 48 of Set 7 | los llanos de aridane
# Processing Record 49 of Set 7 | manadhoo
# Processing Record 0 of Set 8 | batamshinskiy
# Processing Record 1 of Set 8 | nilanga
# Processing Record 2 of Set 8 | lakselv
# Processing Record 3 of Set 8 | port macquarie
# Processing Record 4 of Set 8 | aksarka
# Processing Record 5 of Set 8 | anjozorobe
# Processing Record 6 of Set 8 | la ronge
# Processing Record 7 of Set 8 | yerbogachen
# Processing Record 8 of Set 8 | longview
# Processing Record 9 of Set 8 | road town
# Processing Record 10 of Set 8 | gillette
# Processing Record 11 of Set 8 | margate
# Processing Record 12 of Set 8 | mountain home
# Processing Record 13 of Set 8 | ossora
# Processing Record 14 of Set 8 | halifax
# Processing Record 15 of Set 8 | kurilsk
# Processing Record 16 of Set 8 | muqui
# Processing Record 17 of Set 8 | bandarbeyla
# Processing Record 18 of Set 8 | high rock
# Processing Record 19 of Set 8 | mys shmidta
# City Not Found
# Processing Record 20 of Set 8 | pemangkat
# City Not Found
# Processing Record 21 of Set 8 | neiafu
# Processing Record 22 of Set 8 | saltpond
# Processing Record 23 of Set 8 | amuntai
# Processing Record 24 of Set 8 | bengkulu
# City Not Found
# Processing Record 25 of Set 8 | sinkat
# City Not Found
# Processing Record 26 of Set 8 | matagami
# Processing Record 27 of Set 8 | marawi
# Processing Record 28 of Set 8 | sun city west
# Processing Record 29 of Set 8 | portland
# Processing Record 30 of Set 8 | esna
# Processing Record 31 of Set 8 | abu dhabi
# Processing Record 32 of Set 8 | horki
# Processing Record 33 of Set 8 | mutis
# Processing Record 34 of Set 8 | faya
# Processing Record 35 of Set 8 | ulaanbaatar
# Processing Record 36 of Set 8 | chernenko
# Processing Record 37 of Set 8 | sangar
# Processing Record 38 of Set 8 | bay roberts
# Processing Record 39 of Set 8 | temaraia
# City Not Found
# Processing Record 40 of Set 8 | jacksonville
# Processing Record 41 of Set 8 | manokwari
# Processing Record 42 of Set 8 | kyrksaeterora
# Processing Record 43 of Set 8 | oistins
# Processing Record 44 of Set 8 | iwanai
# Processing Record 45 of Set 8 | dhidhdhoo
# Processing Record 46 of Set 8 | miraflores
# Processing Record 47 of Set 8 | alghero
# Processing Record 48 of Set 8 | breytovo
# Processing Record 49 of Set 8 | mrirt
# City Not Found
# Processing Record 0 of Set 9 | goderich
# Processing Record 1 of Set 9 | dumai
# Processing Record 2 of Set 9 | goundam
# Processing Record 3 of Set 9 | saint-joseph
# Processing Record 4 of Set 9 | vestmanna
# Processing Record 5 of Set 9 | mae sot
# Processing Record 6 of Set 9 | amapa
# Processing Record 7 of Set 9 | aksaray
# Processing Record 8 of Set 9 | rantepao
# Processing Record 9 of Set 9 | kloulklubed
# Processing Record 10 of Set 9 | waingapu
# Processing Record 11 of Set 9 | rawson
# Processing Record 12 of Set 9 | sao joao da barra
# Processing Record 13 of Set 9 | coffs harbour
# Processing Record 14 of Set 9 | roswell
# Processing Record 15 of Set 9 | kalaleh
# Processing Record 16 of Set 9 | oriximina
# Processing Record 17 of Set 9 | ekhabi
# Processing Record 18 of Set 9 | bilma
# Processing Record 19 of Set 9 | toktogul
# Processing Record 20 of Set 9 | baykit
# Processing Record 21 of Set 9 | laizhou
# Processing Record 22 of Set 9 | flinders
# Processing Record 23 of Set 9 | takoradi
# Processing Record 24 of Set 9 | puerto leguizamo
# Processing Record 25 of Set 9 | marysville
# Processing Record 26 of Set 9 | caracollo
# Processing Record 27 of Set 9 | werda
# Processing Record 28 of Set 9 | peterhead
# Processing Record 29 of Set 9 | bairiki
# City Not Found
# Processing Record 30 of Set 9 | bambous virieux
# Processing Record 31 of Set 9 | dalby
# Processing Record 32 of Set 9 | cayenne
# Processing Record 33 of Set 9 | luwingu
# Processing Record 34 of Set 9 | laguna
# Processing Record 35 of Set 9 | san severino marche
# Processing Record 36 of Set 9 | malwan
# City Not Found
# Processing Record 37 of Set 9 | bambanglipuro
# Processing Record 38 of Set 9 | mareeba
# Processing Record 39 of Set 9 | sorland
# Processing Record 40 of Set 9 | suzu
# City Not Found
# Processing Record 41 of Set 9 | omboue
# Processing Record 42 of Set 9 | dourbali
# Processing Record 43 of Set 9 | dongkan
# Processing Record 44 of Set 9 | carman
# Processing Record 45 of Set 9 | leningradskiy
# Processing Record 46 of Set 9 | maria chiquita
# Processing Record 47 of Set 9 | amderma
# City Not Found
# Processing Record 48 of Set 9 | kenai
# Processing Record 49 of Set 9 | burnie
# Processing Record 0 of Set 10 | east london
# Processing Record 1 of Set 10 | lima
# Processing Record 2 of Set 10 | mount darwin
# Processing Record 3 of Set 10 | makakilo city
# Processing Record 4 of Set 10 | paz de ariporo
# City Not Found
# Processing Record 5 of Set 10 | poum
# Processing Record 6 of Set 10 | nenjiang
# Processing Record 7 of Set 10 | kuching
# Processing Record 8 of Set 10 | sabang
# Processing Record 9 of Set 10 | haapu
# City Not Found
# Processing Record 10 of Set 10 | cap malheureux
# Processing Record 11 of Set 10 | avera
# Processing Record 12 of Set 10 | taywarah
# Processing Record 13 of Set 10 | quatre cocos
# Processing Record 14 of Set 10 | safranbolu
# Processing Record 15 of Set 10 | porto novo
# Processing Record 16 of Set 10 | dejen
# Processing Record 17 of Set 10 | kushima
# Processing Record 18 of Set 10 | whitianga
# Processing Record 19 of Set 10 | shingu
# Processing Record 20 of Set 10 | providencia
# Processing Record 21 of Set 10 | nome
# Processing Record 22 of Set 10 | ballina
# Processing Record 23 of Set 10 | bud
# Processing Record 24 of Set 10 | solnechnyy
# Processing Record 25 of Set 10 | sungaipenuh
# Processing Record 26 of Set 10 | celestun
# Processing Record 27 of Set 10 | port lincoln
# Processing Record 28 of Set 10 | havre
# Processing Record 29 of Set 10 | melegnano
# Processing Record 30 of Set 10 | teahupoo
# Processing Record 31 of Set 10 | shitanjing
# Processing Record 32 of Set 10 | anaconda
# Processing Record 33 of Set 10 | beni
# Processing Record 34 of Set 10 | durazno
# Processing Record 35 of Set 10 | andevoranto
# City Not Found
# Processing Record 36 of Set 10 | raudeberg
# Processing Record 37 of Set 10 | meulaboh
# Processing Record 38 of Set 10 | muisne
# Processing Record 39 of Set 10 | bundaberg
# Processing Record 40 of Set 10 | altamira
# Processing Record 41 of Set 10 | alasehir
# Processing Record 42 of Set 10 | baker city
# Processing Record 43 of Set 10 | najran
# Processing Record 44 of Set 10 | pital
# Processing Record 45 of Set 10 | lugus
# Processing Record 46 of Set 10 | umzimvubu
# City Not Found
# Processing Record 47 of Set 10 | gorin
# Processing Record 48 of Set 10 | krasnoselkup
# City Not Found
# Processing Record 49 of Set 10 | lovington
# Processing Record 0 of Set 11 | isangel
# Processing Record 1 of Set 11 | aksu
# Processing Record 2 of Set 11 | ndele
# City Not Found
# Processing Record 3 of Set 11 | aden
# Processing Record 4 of Set 11 | khipro
# Processing Record 5 of Set 11 | khasan
# Processing Record 6 of Set 11 | alta floresta
# Processing Record 7 of Set 11 | antioch
# Processing Record 8 of Set 11 | charters towers
# Processing Record 9 of Set 11 | kindu
# Processing Record 10 of Set 11 | lewisburg
# Processing Record 11 of Set 11 | nogliki
# Processing Record 12 of Set 11 | lasa
# Processing Record 13 of Set 11 | noumea
# Processing Record 14 of Set 11 | vanino
# Processing Record 15 of Set 11 | broken hill
# Processing Record 16 of Set 11 | kermanshah
# Processing Record 17 of Set 11 | krivogastani
# City Not Found
# Processing Record 18 of Set 11 | mwinilunga
# Processing Record 19 of Set 11 | quelimane
# Processing Record 20 of Set 11 | chicama
# Processing Record 21 of Set 11 | killam
# Processing Record 22 of Set 11 | scarborough
# Processing Record 23 of Set 11 | linjiang
# Processing Record 24 of Set 11 | hanzhong
# Processing Record 25 of Set 11 | ugoofaaru
# Processing Record 26 of Set 11 | ekibastuz
# Processing Record 27 of Set 11 | alexandria
# Processing Record 28 of Set 11 | jaguey grande
# Processing Record 29 of Set 11 | umm kaddadah
# Processing Record 30 of Set 11 | barguzin
# Processing Record 31 of Set 11 | qiongshan
# Processing Record 32 of Set 11 | sungairaya
# Processing Record 33 of Set 11 | soyo
# Processing Record 34 of Set 11 | assiniboia
# Processing Record 35 of Set 11 | estancia
# Processing Record 36 of Set 11 | ondorhaan
# City Not Found
# Processing Record 37 of Set 11 | marzuq
# Processing Record 38 of Set 11 | constantine
# Processing Record 39 of Set 11 | palanga
# Processing Record 40 of Set 11 | sturgeon bay
# Processing Record 41 of Set 11 | skibbereen
# Processing Record 42 of Set 11 | tabiauea
# City Not Found
# Processing Record 43 of Set 11 | sechura
# Processing Record 44 of Set 11 | moree
# Processing Record 45 of Set 11 | utiroa
# City Not Found
# Processing Record 46 of Set 11 | san onofre
# Processing Record 47 of Set 11 | saquarema
# Processing Record 48 of Set 11 | sao filipe
# Processing Record 49 of Set 11 | batticaloa
# Processing Record 0 of Set 12 | tucurui
# Processing Record 1 of Set 12 | saint-augustin
# Processing Record 2 of Set 12 | mpanda
# Processing Record 3 of Set 12 | tiznit
# Processing Record 4 of Set 12 | benghazi
# Processing Record 5 of Set 12 | nuevo progreso
# Processing Record 6 of Set 12 | kudahuvadhoo
# Processing Record 7 of Set 12 | digoin
# Processing Record 8 of Set 12 | bonthe
# Processing Record 9 of Set 12 | gazojak
# Processing Record 10 of Set 12 | sistranda
# Processing Record 11 of Set 12 | lompoc
# Processing Record 12 of Set 12 | sept-iles
# Processing Record 13 of Set 12 | phibun mangsahan
# Processing Record 14 of Set 12 | tumannyy
# City Not Found
# Processing Record 15 of Set 12 | mocambique
# City Not Found
# Processing Record 16 of Set 12 | kallaste
# Processing Record 17 of Set 12 | nizhniy kuranakh
# Processing Record 18 of Set 12 | erzin
# Processing Record 19 of Set 12 | longyearbyen
# Processing Record 20 of Set 12 | birjand
# Processing Record 21 of Set 12 | kruisfontein
# Processing Record 22 of Set 12 | gorno-chuyskiy
# City Not Found
# Processing Record 23 of Set 12 | menongue
# Processing Record 24 of Set 12 | fernie
# Processing Record 25 of Set 12 | lincolnton
# Processing Record 26 of Set 12 | nelson bay
# Processing Record 27 of Set 12 | mikuni
# Processing Record 28 of Set 12 | sherghati
# Processing Record 29 of Set 12 | jumla
# Processing Record 30 of Set 12 | varhaug
# Processing Record 31 of Set 12 | santa maria
# Processing Record 32 of Set 12 | fernandopolis
# Processing Record 33 of Set 12 | biu
# Processing Record 34 of Set 12 | kailua
# Processing Record 35 of Set 12 | kieta
# Processing Record 36 of Set 12 | okha
# Processing Record 37 of Set 12 | lancaster
# Processing Record 38 of Set 12 | talnakh
# Processing Record 39 of Set 12 | chalus
# Processing Record 40 of Set 12 | santiago del estero
# Processing Record 41 of Set 12 | verkhnyaya inta
# Processing Record 42 of Set 12 | hasaki
# Processing Record 43 of Set 12 | hashtrud
# Processing Record 44 of Set 12 | takaka
# Processing Record 45 of Set 12 | bargal
# City Not Found
# Processing Record 46 of Set 12 | sorvag
# City Not Found
# Processing Record 47 of Set 12 | buchanan
# Processing Record 48 of Set 12 | san andres
# Processing Record 49 of Set 12 | harper
# Processing Record 0 of Set 13 | lalibela
# Processing Record 1 of Set 13 | herat
# Processing Record 2 of Set 13 | bagdarin
# Processing Record 3 of Set 13 | lovozero
# Processing Record 4 of Set 13 | vadso
# Processing Record 5 of Set 13 | duz
# City Not Found
# Processing Record 6 of Set 13 | puri
# Processing Record 7 of Set 13 | montepuez
# Processing Record 8 of Set 13 | brewster
# Processing Record 9 of Set 13 | narino
# Processing Record 10 of Set 13 | babanusah
# City Not Found
# Processing Record 11 of Set 13 | camopi
# Processing Record 12 of Set 13 | point fortin
# Processing Record 13 of Set 13 | juazeiro
# Processing Record 14 of Set 13 | elko
# Processing Record 15 of Set 13 | aktau
# Processing Record 16 of Set 13 | alugan
# Processing Record 17 of Set 13 | otjiwarongo
# Processing Record 18 of Set 13 | milkovo
# Processing Record 19 of Set 13 | conceicao do araguaia
# Processing Record 20 of Set 13 | te anau
# Processing Record 21 of Set 13 | talcahuano
# Processing Record 22 of Set 13 | san jose
# Processing Record 23 of Set 13 | villanueva
# Processing Record 24 of Set 13 | zaysan
# Processing Record 25 of Set 13 | nantucket
# Processing Record 26 of Set 13 | umm lajj
# Processing Record 27 of Set 13 | saint john
# Processing Record 28 of Set 13 | vilcun
# Processing Record 29 of Set 13 | presidencia roque saenz pena
# Processing Record 30 of Set 13 | malaryta
# Processing Record 31 of Set 13 | tabas

# %%
cities_df.head()
# Out:
#         City Cloudiness Country        Date Humidity    Lat    Long Max Temp  \
# 0   vanavara         32      RU  1545321689       48  60.35  102.28    -9.15
# 1  carnarvon          0      ZA  1545321609       16 -30.97   22.13    85.81
# 2      kapaa         90      US  1545317760       70  22.08 -159.32    69.08
# 3      nalut         80      LY  1545321611       35  31.86   10.98    57.95
# 4  upernavik         64      GL  1545321612      100  72.79  -56.15     7.87
#
#   Wind Speed
# 0       9.78
# 1       4.63
# 2      13.87
# 3       3.74
# 4       8.21

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv("cities_fullframe.csv")
cities_df.head()
# Out:
#         City Cloudiness Country        Date Humidity    Lat    Long Max Temp  \
# 0   vanavara         32      RU  1545321689       48  60.35  102.28    -9.15
# 1  carnarvon          0      ZA  1545321609       16 -30.97   22.13    85.81
# 2      kapaa         90      US  1545317760       70  22.08 -159.32    69.08
# 3      nalut         80      LY  1545321611       35  31.86   10.98    57.95
# 4  upernavik         64      GL  1545321612      100  72.79  -56.15     7.87
#
#   Wind Speed
# 0       9.78
# 1       4.63
# 2      13.87
# 3       3.74
# 4       8.21

# %%
cities_df["Lat"]=pd.to_numeric(cities_df["Lat"])
cities_df["Max Temp"]=pd.to_numeric(cities_df["Max Temp"])
cities_df["Humidity"]=pd.to_numeric(cities_df["Humidity"])
cities_df["Wind Speed"]=pd.to_numeric(cities_df["Wind Speed"])
cities_df["Cloudiness"]=pd.to_numeric(cities_df["Cloudiness"])
ymax=cities_df["Max Temp"].max()+10
ymin=cities_df["Max Temp"].min()-10
xmax=cities_df["Lat"].max()+10
xmin=cities_df["Lat"].min()+10



#cities_df["Date"]=pd.to_float(cities_df["Date"])
#cities_df["Date"]=
#print(time.ctime(cities_df["Date"]))
#print(datetime.datetime.fromtimestamp(date.now()).strftime("%x"))
#print(datetime.datetime(cities_df["Date"].year, cities_df["Date"].month, cities_df["Date"].day))
#print(datetime.datetime.fromtimestamp((cities_df["Date"])))

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#plt.figure(figsize=(8,8))
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City latitude vs Max temperature {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
#cities_df["Max Temp"]=float(cities_df["Max Temp"])
#cities_df["Lat"]=float(cities_df["Lat"])
plt.scatter(cities_df["Lat"], cities_df["Max Temp"],marker="o", alpha=.8,linewidths=1, color="teal", edgecolors='black',label="Urban")

plt.grid()
plt.tight_layout()
plt.show()


plt.savefig("latitude_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#plt.figure(figsize=(10,8))
ymax=100+10
ymin=cities_df["Humidity"].min()-5
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City Latitude vs. Humidity Plot {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
#cities_df["Max Temp"]=float(cities_df["Max Temp"])
#cities_df["Lat"]=float(cities_df["Lat"])
plt.scatter(cities_df["Lat"], cities_df["Humidity"],marker="o", alpha=.6,linewidths=1, color="teal", edgecolors='black',label="Urban")

plt.grid()
#plt.tight_layout()
plt.show()


plt.savefig("latitude_Humidty.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#plt.figure(figsize=(10,8))
ymax=cities_df["Cloudiness"].max()+10
ymin=cities_df["Cloudiness"].min()-5
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City Latitude vs. Cloudiness {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.scatter(cities_df["Lat"], cities_df["Cloudiness"],marker="o", alpha=.6,linewidths=1, color="teal", edgecolors='black',label="Urban")

plt.grid()
#plt.tight_layout()
plt.show()


plt.savefig("latitude_Cloudiness.png")

# %%
#plt.figure(figsize=(10,8))
ymax=cities_df["Wind Speed"].max()+10
ymin=cities_df["Wind Speed"].min()-5
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City Latitude vs. Wind Speed {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")

plt.scatter(cities_df["Lat"], cities_df["Wind Speed"],marker="o", alpha=.6,linewidths=1, color="teal", edgecolors='black',label="Urban")

plt.grid()
#plt.tight_layout()
plt.show()


plt.savefig("latitude_Wind Speed.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
