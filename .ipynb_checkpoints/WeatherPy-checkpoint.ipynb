# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime 
from datetime import date 
import pprint as pp
# Import API key
from config import api_key
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
query_url = f"{url}appid={api_key}&units={units}&q="
#print(query_url)
# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities=[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
       
    
#Print the city count to confirm sufficient count
len(cities)
#print(cities)
cities_df=pd.DataFrame(cities)
cities_df.to_csv(output_data_file)
cities_df=cities_df.rename(columns={0:"City"})
cities_df["Cloudiness"]=""
cities_df["Country"]=""
cities_df["Date"]=""
cities_df["Humidity"]=""
cities_df["Lat"]=""
cities_df["Long"]=""
cities_df["Max Temp"]=""
cities_df["Wind Speed"]=""





#del cities_df[0]

#cities_df["cities"][0]

# %%
cities_df.head()
# Out:
#            City Cloudiness Country Date Humidity Lat Long Max Temp Wind Speed
# 0  constitucion
# 1       ushuaia
# 2      cherskiy
# 3      waingapu
# 4       rikitea

# %%
temp = []
#str=query_url + cities_df["City"][0]
#city1="vaitupu"
#print(str)
#response = requests.get(query_url + city1).json()
#print(response)
#pp.pprint(response)

#print(response["name"])
#print(response["clouds"]["all"])
#print(response["sys"]["country"])
#print(response["dt"])
#print(response["main"]["humidity"])
#print(response["coord"]["lat"])
#print(response["coord"]["lon"])
#print(response["main"]["temp_max"])
#print(response["wind"]["speed"])
#print(response["main"]["pressure"])
ctycntr=1
setcnt =1
#print(response[""])
for index, row in cities_df.iterrows():
    city = row['City']
    
    if (ctycntr%50)==0:
        #print(ctycntr%50)
        ctycntr=1
        setcnt +=1
    else:
        ctycntr+=1 
    response = requests.get(query_url + city).json()
    print(f"Processing Record {ctycntr-1} of Set {setcnt} | {city} ")
    #print(query_url + city)
    if response["cod"]!="404" and response["cod"]!="500" :
        cities_df.loc[index, "Cloudiness"]=response["clouds"]["all"]
        #cities_df["Cloudiness"]=response["clouds"]["all"]
        cities_df.loc[index, "Country"]=response["sys"]["country"]
        #cities_df["Country"]=response["sys"]["country"]
        current_date=datetime.datetime.fromtimestamp(response["dt"]).strftime("%x")
        cities_df.loc[index, "Date"]=response["dt"]
        #cities_df["Date"]=response["dt"]
        cities_df.loc[index, "Humidity"]=response["main"]["humidity"]
        #cities_df["Humidity"]=response["main"]["humidity"]
        cities_df.loc[index, "Lat"]=float(response["coord"]["lat"])
        #cities_df["Lat"]=response["coord"]["lat"]
        cities_df.loc[index, "Long"]=response["coord"]["lon"]
        #cities_df["Long"]=response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"]=float(response["main"]["temp_max"])
        #cities_df["Max Temp"]=response["main"]["temp_max"]
        cities_df.loc[index, "Wind Speed"]=response["wind"]["speed"]
        #cities_df["Wind Speed"]=response["wind"]["speed"]
    else:
        print("City Not Found")
        
#Processing Record 1 of Set 1 | lompoc

 #   lat.append(response['coord']['lat'])
 #   temp.append(response['main']['temp'])

#print(f"The latitude information received is: {lat}")
#print(f"The temperature information received is: {temp}")
# Out:
# Processing Record 1 of Set 1 | constitucion
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | waingapu
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | leningradskiy
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | bom jesus
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | rio grande
# Processing Record 14 of Set 1 | portland
# Processing Record 15 of Set 1 | bandarbeyla
# Processing Record 16 of Set 1 | margate
# Processing Record 17 of Set 1 | bereda
# Processing Record 18 of Set 1 | baoying
# Processing Record 19 of Set 1 | billings
# Processing Record 20 of Set 1 | areka
# Processing Record 21 of Set 1 | svetlogorsk
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | vaitape
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | necochea
# Processing Record 30 of Set 1 | broken hill
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | dutse
# Processing Record 33 of Set 1 | illoqqortoormiut
# City Not Found
# Processing Record 34 of Set 1 | nisia floresta
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | vrangel
# Processing Record 37 of Set 1 | lulea
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | mogadishu
# Processing Record 42 of Set 1 | tautira
# Processing Record 43 of Set 1 | monrovia
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | bengkalis
# City Not Found
# Processing Record 46 of Set 1 | samusu
# City Not Found
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | kavaratti
# Processing Record 49 of Set 1 | pevek
# Processing Record 0 of Set 2 | hobyo
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | bahile
# Processing Record 3 of Set 2 | marienburg
# Processing Record 4 of Set 2 | tura
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | mga
# Processing Record 7 of Set 2 | ozgon
# City Not Found
# Processing Record 8 of Set 2 | agirish
# Processing Record 9 of Set 2 | ampanihy
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | cabo san lucas
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | taolanaro
# City Not Found
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | estelle
# Processing Record 16 of Set 2 | alekseyevsk
# Processing Record 17 of Set 2 | narsaq
# Processing Record 18 of Set 2 | pangai
# Processing Record 19 of Set 2 | luderitz
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | west wendover
# Processing Record 22 of Set 2 | kavieng
# Processing Record 23 of Set 2 | ambodifototra
# City Not Found
# Processing Record 24 of Set 2 | victoria
# Processing Record 25 of Set 2 | cap malheureux
# Processing Record 26 of Set 2 | atsiki
# City Not Found
# Processing Record 27 of Set 2 | belushya guba
# City Not Found
# Processing Record 28 of Set 2 | sao jose da coroa grande
# Processing Record 29 of Set 2 | kieta
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | anadyr
# Processing Record 33 of Set 2 | chekmagush
# Processing Record 34 of Set 2 | zheleznodorozhnyy
# Processing Record 35 of Set 2 | maralal
# Processing Record 36 of Set 2 | hvittingfoss
# Processing Record 37 of Set 2 | singaraja
# Processing Record 38 of Set 2 | lovington
# Processing Record 39 of Set 2 | inderborskiy
# City Not Found
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | chokwe
# City Not Found
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | tual
# Processing Record 45 of Set 2 | ardea
# Processing Record 46 of Set 2 | aklavik
# Processing Record 47 of Set 2 | puerto del rosario
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | nueva gerona
# Processing Record 0 of Set 3 | kortkeros
# Processing Record 1 of Set 3 | bowen
# Processing Record 2 of Set 3 | iqaluit
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | san patricio
# Processing Record 5 of Set 3 | saint-michel-des-saints
# Processing Record 6 of Set 3 | mandalgovi
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | batagay-alyta
# Processing Record 9 of Set 3 | amderma
# City Not Found
# Processing Record 10 of Set 3 | nizhnyaya tavda
# Processing Record 11 of Set 3 | fortuna
# Processing Record 12 of Set 3 | nizhneyansk
# City Not Found
# Processing Record 13 of Set 3 | isla mujeres
# Processing Record 14 of Set 3 | barentsburg
# City Not Found
# Processing Record 15 of Set 3 | saint-pierre
# Processing Record 16 of Set 3 | salair
# Processing Record 17 of Set 3 | baruun-urt
# Processing Record 18 of Set 3 | qiongshan
# Processing Record 19 of Set 3 | maniitsoq
# Processing Record 20 of Set 3 | sao filipe
# Processing Record 21 of Set 3 | paratebueno
# Processing Record 22 of Set 3 | bakchar
# Processing Record 23 of Set 3 | lasa
# Processing Record 24 of Set 3 | jamestown
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | port augusta
# Processing Record 27 of Set 3 | noumea
# Processing Record 28 of Set 3 | salinas
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | kawalu
# Processing Record 31 of Set 3 | cape town
# Processing Record 32 of Set 3 | huittinen
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | mugur-aksy
# Processing Record 36 of Set 3 | roma
# Processing Record 37 of Set 3 | southbridge
# Processing Record 38 of Set 3 | zhigansk
# Processing Record 39 of Set 3 | netrakona
# Processing Record 40 of Set 3 | adrar
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | coihaique
# Processing Record 43 of Set 3 | panguipulli
# Processing Record 44 of Set 3 | torbay
# Processing Record 45 of Set 3 | erenhot
# Processing Record 46 of Set 3 | caravelas
# Processing Record 47 of Set 3 | tasiilaq
# Processing Record 48 of Set 3 | rio gallegos
# Processing Record 49 of Set 3 | puerto carreno
# Processing Record 0 of Set 4 | klaksvik
# Processing Record 1 of Set 4 | teya
# Processing Record 2 of Set 4 | antsohihy
# Processing Record 3 of Set 4 | catamarca
# City Not Found
# Processing Record 4 of Set 4 | ouesso
# Processing Record 5 of Set 4 | kudahuvadhoo
# Processing Record 6 of Set 4 | port-gentil
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | tsihombe
# City Not Found
# Processing Record 9 of Set 4 | port lincoln
# Processing Record 10 of Set 4 | yashkul
# Processing Record 11 of Set 4 | normandin
# Processing Record 12 of Set 4 | frederikshavn
# Processing Record 13 of Set 4 | barrow
# Processing Record 14 of Set 4 | porbandar
# Processing Record 15 of Set 4 | abyek
# Processing Record 16 of Set 4 | coos bay
# Processing Record 17 of Set 4 | halalo
# City Not Found
# Processing Record 18 of Set 4 | denpasar
# Processing Record 19 of Set 4 | mahajanga
# Processing Record 20 of Set 4 | tarko-sale
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | talnakh
# Processing Record 23 of Set 4 | pilar
# Processing Record 24 of Set 4 | goderich
# Processing Record 25 of Set 4 | caboolture
# Processing Record 26 of Set 4 | shimoda
# Processing Record 27 of Set 4 | bosaso
# Processing Record 28 of Set 4 | iquique
# Processing Record 29 of Set 4 | ewa beach
# Processing Record 30 of Set 4 | castro
# Processing Record 31 of Set 4 | bluff
# Processing Record 32 of Set 4 | mys shmidta
# City Not Found
# Processing Record 33 of Set 4 | atlantic city
# City Not Found
# Processing Record 34 of Set 4 | dabakala
# Processing Record 35 of Set 4 | lubumbashi
# Processing Record 36 of Set 4 | novaya ladoga
# Processing Record 37 of Set 4 | la ronge
# Processing Record 38 of Set 4 | melfi
# Processing Record 39 of Set 4 | slave lake
# Processing Record 40 of Set 4 | naze
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | longyearbyen
# Processing Record 43 of Set 4 | aflu
# City Not Found
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | abashiri
# Processing Record 46 of Set 4 | vardo
# Processing Record 47 of Set 4 | saldanha
# Processing Record 48 of Set 4 | mercedes
# Processing Record 49 of Set 4 | lagoa
# Processing Record 0 of Set 5 | syrskoye
# Processing Record 1 of Set 5 | paamiut
# Processing Record 2 of Set 5 | hofn
# Processing Record 3 of Set 5 | arica
# Processing Record 4 of Set 5 | samalaeulu
# City Not Found
# Processing Record 5 of Set 5 | dingle
# Processing Record 6 of Set 5 | new norfolk
# Processing Record 7 of Set 5 | coquimbo
# Processing Record 8 of Set 5 | sentyabrskiy
# City Not Found
# Processing Record 9 of Set 5 | grand gaube
# Processing Record 10 of Set 5 | vila franca do campo
# Processing Record 11 of Set 5 | georgetown
# Processing Record 12 of Set 5 | puerto baquerizo moreno
# Processing Record 13 of Set 5 | santa cruz
# Processing Record 14 of Set 5 | vestmannaeyjar
# Processing Record 15 of Set 5 | udachnyy
# Processing Record 16 of Set 5 | skalistyy
# City Not Found
# Processing Record 17 of Set 5 | yanchukan
# City Not Found
# Processing Record 18 of Set 5 | neryungri
# Processing Record 19 of Set 5 | rosa zarate
# Processing Record 20 of Set 5 | agadir
# Processing Record 21 of Set 5 | shingu
# Processing Record 22 of Set 5 | xiongshi
# City Not Found
# Processing Record 23 of Set 5 | bajo baudo
# City Not Found
# Processing Record 24 of Set 5 | port hardy
# Processing Record 25 of Set 5 | merauke
# Processing Record 26 of Set 5 | maunabo
# Processing Record 27 of Set 5 | clyde river
# Processing Record 28 of Set 5 | chagda
# City Not Found
# Processing Record 29 of Set 5 | bathsheba
# Processing Record 30 of Set 5 | winnemucca
# Processing Record 31 of Set 5 | birin
# Processing Record 32 of Set 5 | vanavara
# Processing Record 33 of Set 5 | bose
# Processing Record 34 of Set 5 | calabozo
# Processing Record 35 of Set 5 | attawapiskat
# City Not Found
# Processing Record 36 of Set 5 | pierre
# Processing Record 37 of Set 5 | svetlyy
# City Not Found
# Processing Record 38 of Set 5 | keffi
# Processing Record 39 of Set 5 | montepuez
# Processing Record 40 of Set 5 | pihuamo
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | mehamn
# Processing Record 43 of Set 5 | waipawa
# Processing Record 44 of Set 5 | banda aceh
# Processing Record 45 of Set 5 | bonnyville
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | hermiston
# Processing Record 48 of Set 5 | tessalit
# Processing Record 49 of Set 5 | sitka
# Processing Record 0 of Set 6 | lavrentiya
# Processing Record 1 of Set 6 | hamilton
# Processing Record 2 of Set 6 | shelburne
# Processing Record 3 of Set 6 | te anau
# Processing Record 4 of Set 6 | kargasok
# Processing Record 5 of Set 6 | makakilo city
# Processing Record 6 of Set 6 | nuuk
# Processing Record 7 of Set 6 | khani
# Processing Record 8 of Set 6 | mount gambier
# Processing Record 9 of Set 6 | laguna
# Processing Record 10 of Set 6 | roald
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | soc trang
# Processing Record 13 of Set 6 | sulangan
# Processing Record 14 of Set 6 | ngama
# City Not Found
# Processing Record 15 of Set 6 | abha
# Processing Record 16 of Set 6 | kainantu
# Processing Record 17 of Set 6 | prince albert
# Processing Record 18 of Set 6 | lorengau
# Processing Record 19 of Set 6 | rawson
# Processing Record 20 of Set 6 | oda
# Processing Record 21 of Set 6 | east london
# Processing Record 22 of Set 6 | mount isa
# Processing Record 23 of Set 6 | gatton
# Processing Record 24 of Set 6 | richards bay
# Processing Record 25 of Set 6 | grand river south east
# City Not Found
# Processing Record 26 of Set 6 | palabuhanratu
# City Not Found
# Processing Record 27 of Set 6 | palana
# Processing Record 28 of Set 6 | walvis bay
# Processing Record 29 of Set 6 | louis trichardt
# Processing Record 30 of Set 6 | sindand
# City Not Found
# Processing Record 31 of Set 6 | santa marta
# Processing Record 32 of Set 6 | jalu
# Processing Record 33 of Set 6 | inta
# Processing Record 34 of Set 6 | shumikha
# Processing Record 35 of Set 6 | saint george
# Processing Record 36 of Set 6 | kaitangata
# Processing Record 37 of Set 6 | isangel
# Processing Record 38 of Set 6 | sibolga
# Processing Record 39 of Set 6 | bitung
# Processing Record 40 of Set 6 | mount pleasant
# Processing Record 41 of Set 6 | port elizabeth
# Processing Record 42 of Set 6 | rudbar
# City Not Found
# Processing Record 43 of Set 6 | obera
# Processing Record 44 of Set 6 | cherusti
# Processing Record 45 of Set 6 | boatlaname
# City Not Found
# Processing Record 46 of Set 6 | linchuan
# City Not Found
# Processing Record 47 of Set 6 | nome
# Processing Record 48 of Set 6 | nizhneangarsk
# Processing Record 49 of Set 6 | vonnu
# City Not Found
# Processing Record 0 of Set 7 | taburi
# City Not Found
# Processing Record 1 of Set 7 | neiafu
# Processing Record 2 of Set 7 | kidal
# Processing Record 3 of Set 7 | saint-denis
# Processing Record 4 of Set 7 | gobabis
# Processing Record 5 of Set 7 | cardiff
# Processing Record 6 of Set 7 | kibala
# Processing Record 7 of Set 7 | nanortalik
# Processing Record 8 of Set 7 | morshansk
# Processing Record 9 of Set 7 | husavik
# Processing Record 10 of Set 7 | lahij
# Processing Record 11 of Set 7 | san luis
# Processing Record 12 of Set 7 | sidi ali
# Processing Record 13 of Set 7 | velizh
# Processing Record 14 of Set 7 | chuy
# Processing Record 15 of Set 7 | peniche
# Processing Record 16 of Set 7 | kisanga
# Processing Record 17 of Set 7 | chokurdakh
# Processing Record 18 of Set 7 | amudat
# Processing Record 19 of Set 7 | quatre cocos
# Processing Record 20 of Set 7 | salalah
# Processing Record 21 of Set 7 | itoman
# Processing Record 22 of Set 7 | ruteng
# Processing Record 23 of Set 7 | umm lajj
# Processing Record 24 of Set 7 | kuvshinovo
# Processing Record 25 of Set 7 | grindavik
# Processing Record 26 of Set 7 | veraval
# Processing Record 27 of Set 7 | beyneu
# Processing Record 28 of Set 7 | saleaula
# City Not Found
# Processing Record 29 of Set 7 | esperance
# Processing Record 30 of Set 7 | kegayli
# City Not Found
# Processing Record 31 of Set 7 | neepawa
# Processing Record 32 of Set 7 | alofi
# Processing Record 33 of Set 7 | miracema do tocantins
# Processing Record 34 of Set 7 | kamina
# Processing Record 35 of Set 7 | mashivka
# Processing Record 36 of Set 7 | cayenne
# Processing Record 37 of Set 7 | helong
# Processing Record 38 of Set 7 | sarangani
# Processing Record 39 of Set 7 | kleinmachnow
# Processing Record 40 of Set 7 | alcains
# Processing Record 41 of Set 7 | beloha
# Processing Record 42 of Set 7 | novopokrovka
# Processing Record 43 of Set 7 | sibu
# Processing Record 44 of Set 7 | tokmak
# Processing Record 45 of Set 7 | kraslava
# Processing Record 46 of Set 7 | pointe michel
# Processing Record 47 of Set 7 | yar-sale
# Processing Record 48 of Set 7 | usinsk
# Processing Record 49 of Set 7 | chicama
# Processing Record 0 of Set 8 | talas
# Processing Record 1 of Set 8 | tumannyy
# City Not Found
# Processing Record 2 of Set 8 | galgani
# City Not Found
# Processing Record 3 of Set 8 | sisimiut
# Processing Record 4 of Set 8 | rapid valley
# Processing Record 5 of Set 8 | moyale
# Processing Record 6 of Set 8 | ust-tsilma
# Processing Record 7 of Set 8 | shchelyayur
# City Not Found
# Processing Record 8 of Set 8 | cabedelo
# Processing Record 9 of Set 8 | ternate
# Processing Record 10 of Set 8 | vaitupu
# City Not Found
# Processing Record 11 of Set 8 | lagos
# Processing Record 12 of Set 8 | keetmanshoop
# Processing Record 13 of Set 8 | ballina
# Processing Record 14 of Set 8 | rybinsk
# Processing Record 15 of Set 8 | yanam
# Processing Record 16 of Set 8 | bam
# Processing Record 17 of Set 8 | chongwe
# Processing Record 18 of Set 8 | marcona
# City Not Found
# Processing Record 19 of Set 8 | yulara
# Processing Record 20 of Set 8 | hearst
# Processing Record 21 of Set 8 | nelson bay
# Processing Record 22 of Set 8 | bambous virieux
# Processing Record 23 of Set 8 | eldorado
# Processing Record 24 of Set 8 | sogdiondon
# City Not Found
# Processing Record 25 of Set 8 | matara
# Processing Record 26 of Set 8 | taltal
# Processing Record 27 of Set 8 | marsh harbour
# Processing Record 28 of Set 8 | caraquet
# Processing Record 29 of Set 8 | bethel
# Processing Record 30 of Set 8 | bargarh
# Processing Record 31 of Set 8 | mongoumba
# Processing Record 32 of Set 8 | turukhansk
# Processing Record 33 of Set 8 | tikhmenevo
# City Not Found
# Processing Record 34 of Set 8 | qasigiannguit
# Processing Record 35 of Set 8 | san jose de los arroyos
# City Not Found
# Processing Record 36 of Set 8 | beringovskiy
# Processing Record 37 of Set 8 | oranjestad
# Processing Record 38 of Set 8 | ukholovo
# Processing Record 39 of Set 8 | sorong
# Processing Record 40 of Set 8 | sao miguel do araguaia
# Processing Record 41 of Set 8 | haines junction
# Processing Record 42 of Set 8 | bangkalan
# Processing Record 43 of Set 8 | san rafael
# Processing Record 44 of Set 8 | acarau
# City Not Found
# Processing Record 45 of Set 8 | kurumkan
# Processing Record 46 of Set 8 | mikhaylovka
# Processing Record 47 of Set 8 | tsabong
# Processing Record 48 of Set 8 | ferry pass
# Processing Record 49 of Set 8 | camacha
# Processing Record 0 of Set 9 | kemin
# Processing Record 1 of Set 9 | osakarovka
# Processing Record 2 of Set 9 | comodoro rivadavia
# Processing Record 3 of Set 9 | grinnell
# Processing Record 4 of Set 9 | lake havasu city
# Processing Record 5 of Set 9 | patnagarh
# Processing Record 6 of Set 9 | los llanos de aridane
# Processing Record 7 of Set 9 | padang
# Processing Record 8 of Set 9 | bodden town
# Processing Record 9 of Set 9 | bairiki
# City Not Found
# Processing Record 10 of Set 9 | longlac
# City Not Found
# Processing Record 11 of Set 9 | moose factory
# Processing Record 12 of Set 9 | moree
# Processing Record 13 of Set 9 | berdigestyakh
# Processing Record 14 of Set 9 | halifax
# Processing Record 15 of Set 9 | atar
# Processing Record 16 of Set 9 | aquitania
# Processing Record 17 of Set 9 | mitchell
# Processing Record 18 of Set 9 | sherlovaya gora
# Processing Record 19 of Set 9 | ostrovnoy
# Processing Record 20 of Set 9 | abu kamal
# Processing Record 21 of Set 9 | preobrazheniye
# Processing Record 22 of Set 9 | kazalinsk
# City Not Found
# Processing Record 23 of Set 9 | andrelandia
# City Not Found
# Processing Record 24 of Set 9 | yerbogachen
# Processing Record 25 of Set 9 | novikovo
# Processing Record 26 of Set 9 | faanui
# Processing Record 27 of Set 9 | dalbandin
# Processing Record 28 of Set 9 | kachug
# Processing Record 29 of Set 9 | dongying
# Processing Record 30 of Set 9 | ust-koksa
# Processing Record 31 of Set 9 | bolungarvik
# City Not Found
# Processing Record 32 of Set 9 | tahta
# City Not Found
# Processing Record 33 of Set 9 | lancaster
# Processing Record 34 of Set 9 | kuala terengganu
# Processing Record 35 of Set 9 | qaqortoq
# Processing Record 36 of Set 9 | huaraz
# Processing Record 37 of Set 9 | kalevala
# Processing Record 38 of Set 9 | rolim de moura
# City Not Found
# Processing Record 39 of Set 9 | demirci
# Processing Record 40 of Set 9 | belyy yar
# Processing Record 41 of Set 9 | deputatskiy
# Processing Record 42 of Set 9 | saint anthony
# Processing Record 43 of Set 9 | olimpia
# Processing Record 44 of Set 9 | krasnoselkup
# City Not Found
# Processing Record 45 of Set 9 | sabha
# Processing Record 46 of Set 9 | opuwo
# Processing Record 47 of Set 9 | lobito
# Processing Record 48 of Set 9 | makinsk
# Processing Record 49 of Set 9 | askarovo
# Processing Record 0 of Set 10 | hirara
# Processing Record 1 of Set 10 | camabatela
# Processing Record 2 of Set 10 | hovd
# Processing Record 3 of Set 10 | sagua la grande
# Processing Record 4 of Set 10 | kununurra
# Processing Record 5 of Set 10 | ancud
# Processing Record 6 of Set 10 | abu samrah
# Processing Record 7 of Set 10 | north bend
# Processing Record 8 of Set 10 | charyshskoye
# Processing Record 9 of Set 10 | bira
# Processing Record 10 of Set 10 | louisbourg
# City Not Found
# Processing Record 11 of Set 10 | malakal
# City Not Found
# Processing Record 12 of Set 10 | san pedro
# Processing Record 13 of Set 10 | morondava
# Processing Record 14 of Set 10 | meulaboh
# Processing Record 15 of Set 10 | pokosnoye
# Processing Record 16 of Set 10 | sept-iles
# Processing Record 17 of Set 10 | sao joao da barra
# Processing Record 18 of Set 10 | sagay
# Processing Record 19 of Set 10 | terrace
# Processing Record 20 of Set 10 | taipei
# Processing Record 21 of Set 10 | gorontalo
# Processing Record 22 of Set 10 | vostok
# Processing Record 23 of Set 10 | bossangoa
# Processing Record 24 of Set 10 | bargal
# City Not Found
# Processing Record 25 of Set 10 | barra patuca
# Processing Record 26 of Set 10 | ucluelet
# Processing Record 27 of Set 10 | villamontes
# Processing Record 28 of Set 10 | kesennuma
# City Not Found
# Processing Record 29 of Set 10 | hasaki
# Processing Record 30 of Set 10 | sault sainte marie
# Processing Record 31 of Set 10 | cartagena
# Processing Record 32 of Set 10 | penticton
# Processing Record 33 of Set 10 | chunskiy
# Processing Record 34 of Set 10 | yumen
# Processing Record 35 of Set 10 | piastow
# Processing Record 36 of Set 10 | bud
# Processing Record 37 of Set 10 | provideniya
# Processing Record 38 of Set 10 | kismayo
# City Not Found
# Processing Record 39 of Set 10 | taoudenni
# Processing Record 40 of Set 10 | maun
# Processing Record 41 of Set 10 | nyurba
# Processing Record 42 of Set 10 | my tho
# Processing Record 43 of Set 10 | puerto escondido
# Processing Record 44 of Set 10 | dong hoi
# Processing Record 45 of Set 10 | humaita
# Processing Record 46 of Set 10 | sur
# Processing Record 47 of Set 10 | surandai
# Processing Record 48 of Set 10 | kiama
# Processing Record 49 of Set 10 | syava
# Processing Record 0 of Set 11 | atherton
# Processing Record 1 of Set 11 | raton
# Processing Record 2 of Set 11 | chernyshevskiy
# Processing Record 3 of Set 11 | pisco
# Processing Record 4 of Set 11 | muroto
# Processing Record 5 of Set 11 | mendahara
# City Not Found
# Processing Record 6 of Set 11 | natchitoches
# Processing Record 7 of Set 11 | gayeri
# Processing Record 8 of Set 11 | porto santo
# City Not Found
# Processing Record 9 of Set 11 | zaykovo
# Processing Record 10 of Set 11 | camrose
# Processing Record 11 of Set 11 | havoysund
# Processing Record 12 of Set 11 | tokur
# Processing Record 13 of Set 11 | manokwari
# Processing Record 14 of Set 11 | mormugao
# City Not Found
# Processing Record 15 of Set 11 | cockburn town
# Processing Record 16 of Set 11 | birjand
# Processing Record 17 of Set 11 | goulburn
# Processing Record 18 of Set 11 | bilibino
# Processing Record 19 of Set 11 | bahadurganj
# Processing Record 20 of Set 11 | pandan
# Processing Record 21 of Set 11 | rajec
# Processing Record 22 of Set 11 | andros
# Processing Record 23 of Set 11 | maragogi
# Processing Record 24 of Set 11 | asau
# City Not Found
# Processing Record 25 of Set 11 | makokou
# Processing Record 26 of Set 11 | kachikau
# City Not Found
# Processing Record 27 of Set 11 | tabiauea
# City Not Found
# Processing Record 28 of Set 11 | sobolevo
# Processing Record 29 of Set 11 | havre-saint-pierre
# Processing Record 30 of Set 11 | kupang
# Processing Record 31 of Set 11 | eagle pass
# Processing Record 32 of Set 11 | mutare
# Processing Record 33 of Set 11 | lamas
# Processing Record 34 of Set 11 | karamay
# City Not Found
# Processing Record 35 of Set 11 | port blair
# Processing Record 36 of Set 11 | marzuq
# Processing Record 37 of Set 11 | petropavlovka
# Processing Record 38 of Set 11 | olafsvik
# City Not Found
# Processing Record 39 of Set 11 | nguiu
# City Not Found
# Processing Record 40 of Set 11 | guangyuan
# Processing Record 41 of Set 11 | dunedin
# Processing Record 42 of Set 11 | the valley
# Processing Record 43 of Set 11 | tirumullaivasal
# Processing Record 44 of Set 11 | sydney mines
# Processing Record 45 of Set 11 | palladam
# Processing Record 46 of Set 11 | fallon
# Processing Record 47 of Set 11 | drovyanaya
# Processing Record 48 of Set 11 | huarmey
# Processing Record 49 of Set 11 | mackay
# Processing Record 0 of Set 12 | ashqelon
# Processing Record 1 of Set 12 | kokopo
# Processing Record 2 of Set 12 | hualmay
# Processing Record 3 of Set 12 | alibag
# Processing Record 4 of Set 12 | sinnamary
# Processing Record 5 of Set 12 | bonavista
# Processing Record 6 of Set 12 | binga
# Processing Record 7 of Set 12 | tutoia
# Processing Record 8 of Set 12 | avera
# Processing Record 9 of Set 12 | samarai
# Processing Record 10 of Set 12 | yen bai
# Processing Record 11 of Set 12 | bara
# Processing Record 12 of Set 12 | vastervik
# City Not Found
# Processing Record 13 of Set 12 | seguela
# Processing Record 14 of Set 12 | fairbanks
# Processing Record 15 of Set 12 | bambanglipuro
# Processing Record 16 of Set 12 | faya
# Processing Record 17 of Set 12 | kahului
# Processing Record 18 of Set 12 | pesqueira
# Processing Record 19 of Set 12 | high prairie
# Processing Record 20 of Set 12 | monte escobedo
# Processing Record 21 of Set 12 | kyra
# City Not Found
# Processing Record 22 of Set 12 | inhambane
# Processing Record 23 of Set 12 | salamiyah
# Processing Record 24 of Set 12 | curup
# Processing Record 25 of Set 12 | vestmanna
# Processing Record 26 of Set 12 | kailua
# Processing Record 27 of Set 12 | aubenas
# Processing Record 28 of Set 12 | rudnyy
# Processing Record 29 of Set 12 | klyuchi
# Processing Record 30 of Set 12 | papetoai
# Processing Record 31 of Set 12 | muros
# Processing Record 32 of Set 12 | souillac
# Processing Record 33 of Set 12 | kirakira
# Processing Record 34 of Set 12 | semey
# Processing Record 35 of Set 12 | saint-marc-des-carrieres
# Processing Record 36 of Set 12 | khvorostyanka
# Processing Record 37 of Set 12 | mysliborz
# Processing Record 38 of Set 12 | bilma
# Processing Record 39 of Set 12 | sarahan
# Processing Record 40 of Set 12 | korla
# City Not Found
# Processing Record 41 of Set 12 | komsomolskiy
# Processing Record 42 of Set 12 | cazaje
# City Not Found
# Processing Record 43 of Set 12 | guerrero negro
# Processing Record 44 of Set 12 | stornoway
# City Not Found
# Processing Record 45 of Set 12 | macaboboni
# City Not Found
# Processing Record 46 of Set 12 | keflavik
# Processing Record 47 of Set 12 | shirakawa
# Processing Record 48 of Set 12 | sabang
# Processing Record 49 of Set 12 | falealupo
# City Not Found
# Processing Record 0 of Set 13 | tignere
# Processing Record 1 of Set 13 | simpang
# Processing Record 2 of Set 13 | chunoyar
# Processing Record 3 of Set 13 | chenghai
# Processing Record 4 of Set 13 | atambua
# Processing Record 5 of Set 13 | nhamunda
# Processing Record 6 of Set 13 | egvekinot
# Processing Record 7 of Set 13 | katsuura
# Processing Record 8 of Set 13 | solnechnyy
# Processing Record 9 of Set 13 | bacuit
# City Not Found
# Processing Record 10 of Set 13 | paita
# Processing Record 11 of Set 13 | patiya
# Processing Record 12 of Set 13 | yeppoon
# Processing Record 13 of Set 13 | oranjemund
# Processing Record 14 of Set 13 | rexburg
# Processing Record 15 of Set 13 | kibara
# Processing Record 16 of Set 13 | labuhan
# Processing Record 17 of Set 13 | kijang
# Processing Record 18 of Set 13 | kruisfontein
# Processing Record 19 of Set 13 | taozhuang
# Processing Record 20 of Set 13 | kumi
# Processing Record 21 of Set 13 | namibe
# Processing Record 22 of Set 13 | yarensk
# Processing Record 23 of Set 13 | luanda
# Processing Record 24 of Set 13 | isilkul
# Processing Record 25 of Set 13 | urumqi
# City Not Found
# Processing Record 26 of Set 13 | iracoubo
# Processing Record 27 of Set 13 | kumta
# Processing Record 28 of Set 13 | tamale
# Processing Record 29 of Set 13 | hambantota
# Processing Record 30 of Set 13 | whitianga
# Processing Record 31 of Set 13 | agadez

# %%
cities_df.head()
# Out:
#            City Cloudiness Country        Date Humidity    Lat    Long  \
# 0  constitucion          5      MX  1545410580       33  23.99 -104.67
# 1       ushuaia         75      AR  1545411600       81 -54.81  -68.31
# 2      cherskiy         48      RU  1545414868       60  68.75   161.3
# 3      waingapu         24      ID  1545414868      100  -9.65  120.26
# 4       rikitea         56      PF  1545414868      100 -23.12 -134.97
#
#   Max Temp Wind Speed
# 0     46.4        4.7
# 1     53.6      31.09
# 2   -33.54       2.73
# 3    73.61       5.75
# 4    77.21       12.8

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv("cities_fullframe.csv")
cities_df.head()
# Out:
#            City Cloudiness Country        Date Humidity    Lat    Long  \
# 0  constitucion          5      MX  1545410580       33  23.99 -104.67
# 1       ushuaia         75      AR  1545411600       81 -54.81  -68.31
# 2      cherskiy         48      RU  1545414868       60  68.75   161.3
# 3      waingapu         24      ID  1545414868      100  -9.65  120.26
# 4       rikitea         56      PF  1545414868      100 -23.12 -134.97
#
#   Max Temp Wind Speed
# 0     46.4        4.7
# 1     53.6      31.09
# 2   -33.54       2.73
# 3    73.61       5.75
# 4    77.21       12.8

# %%
cities_df["Lat"]=pd.to_numeric(cities_df["Lat"])
cities_df["Max Temp"]=pd.to_numeric(cities_df["Max Temp"])
cities_df["Humidity"]=pd.to_numeric(cities_df["Humidity"])
cities_df["Wind Speed"]=pd.to_numeric(cities_df["Wind Speed"])
cities_df["Cloudiness"]=pd.to_numeric(cities_df["Cloudiness"])
ymax=cities_df["Max Temp"].max()+10
ymin=cities_df["Max Temp"].min()-10
xmax=cities_df["Lat"].max()+10
xmin=cities_df["Lat"].min()+10



#cities_df["Date"]=pd.to_float(cities_df["Date"])
#cities_df["Date"]=
#print(time.ctime(cities_df["Date"]))
#print(datetime.datetime.fromtimestamp(date.now()).strftime("%x"))
#print(datetime.datetime(cities_df["Date"].year, cities_df["Date"].month, cities_df["Date"].day))
#print(datetime.datetime.fromtimestamp((cities_df["Date"])))

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#plt.figure(figsize=(8,8))
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City latitude vs Max temperature {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
#cities_df["Max Temp"]=float(cities_df["Max Temp"])
#cities_df["Lat"]=float(cities_df["Lat"])
plt.scatter(cities_df["Lat"], cities_df["Max Temp"],marker="o", alpha=.8,linewidths=1, color="teal", edgecolors='black',label="Urban")

plt.grid()
plt.tight_layout()
plt.show()


plt.savefig("latitude_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#plt.figure(figsize=(10,8))
ymax=100+10
ymin=cities_df["Humidity"].min()-5
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City Latitude vs. Humidity Plot {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
#cities_df["Max Temp"]=float(cities_df["Max Temp"])
#cities_df["Lat"]=float(cities_df["Lat"])
plt.scatter(cities_df["Lat"], cities_df["Humidity"],marker="o", alpha=.6,linewidths=1, color="teal", edgecolors='black',label="Urban")

plt.grid()
#plt.tight_layout()
plt.show()


plt.savefig("latitude_Humidty.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#plt.figure(figsize=(10,8))
ymax=cities_df["Cloudiness"].max()+10
ymin=cities_df["Cloudiness"].min()-5
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City Latitude vs. Cloudiness {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.scatter(cities_df["Lat"], cities_df["Cloudiness"],marker="o", alpha=.6,linewidths=1, color="teal", edgecolors='black',label="Urban")

plt.grid()
#plt.tight_layout()
plt.show()


plt.savefig("latitude_Cloudiness.png")

# %%
#plt.figure(figsize=(10,8))
ymax=cities_df["Wind Speed"].max()+10
ymin=cities_df["Wind Speed"].min()-5
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)

plt.title(f"City Latitude vs. Wind Speed {current_date}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")

plt.scatter(cities_df["Lat"], cities_df["Wind Speed"],marker="o", alpha=.6,linewidths=1, color="teal", edgecolors='black',label="Urban")

plt.grid()
#plt.tight_layout()
plt.show()


plt.savefig("latitude_Wind Speed.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
